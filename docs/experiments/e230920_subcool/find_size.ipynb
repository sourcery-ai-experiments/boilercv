# %% [markdown]
# # Find size
#
# Find bubble size using two different approaches.

# %%
import colorcet  # noqa: F401  # Registers "cet_" prefixed colormaps in plt.colormaps
from geopandas import GeoDataFrame, points_from_xy
from matplotlib import colormaps  # type: ignore  # pyright 1.1.317
from numpy import pi, sqrt
from pandas import DataFrame, IndexSlice, NamedAgg
from seaborn import scatterplot
from shapely import LinearRing, Polygon
from src.boilercv.docs import HIDE

from boilercv.data.sets import get_contours_df, get_dataset
from boilercv.docs import init, nowarn, style_df
from boilercv.images import scale_bool
from boilercv.stages.experiments.e230920_subcool import GBC, bounded_ax

init()

with nowarn(capture=True):
    import trackpy as tp

tp.quiet()

WARM_PALETTE = colormaps["cet_glasbey_warm"]
"""For plotting one approach."""
COOL_PALETTE = colormaps["cet_glasbey_cool"]
"""For plotting the other approach."""
GET_TRACKPY_OBJECTS = True
"""Whether to get objects using the Trackpy approach."""
TIME = "2023-09-20T17:14:18"
"""Trial."""
STEP = 10
"""Frame step size."""
STOP = 3
"""Last frame to analyze."""
FRAMES: list[int | None] | None = [None, *[STEP * frame for frame in (STOP, 1)]]
"""Frames.

A list that will become a slice. Not a tuple because `ploomber_engine` can't inject
tuples. Here we automatically scale the frame to stop at by the step size.
"""
GUESS_DIAMETER = 21
"""Guess diameter for the Trackpy approach. (px)"""
COLS = ["y", "x", "frame", "size"]
"""Columns to compare across approaches."""

HIDE

# %% [markdown]
# ## Data
#
# Load a video of filled contours and the contour loci and plot a composite of all frames to analyze.

# %%
PATH_TIME = TIME.replace(":", "-")
"""Timestamp suitable for paths.

Also used in notebook parametrization.
"""

frames = slice(*FRAMES) if isinstance(FRAMES, list) else slice(None)  # type: ignore  # pyright: 1.1.336
filled_contours = scale_bool(
    get_dataset(PATH_TIME, frame=frames, stage="filled")["video"]
)
contours_df = get_contours_df(PATH_TIME)
composite_video = filled_contours.max("frame").values
with bounded_ax(composite_video) as ax:
    ax.imshow(~composite_video, alpha=0.4)

HIDE

# %% [markdown]
# ## Find size from filled contours using Trackpy
#
# Use Trackpy to find bubble size given the filled contours.

# %%
if GET_TRACKPY_OBJECTS:
    tp_objects = (
        tp.batch(
            frames=filled_contours.values, diameter=GUESS_DIAMETER, characterize=True
        ).assign(
            frame=lambda df: df.frame.replace(
                dict(enumerate(filled_contours.frame.values))
            )
        )
    ).loc[:, COLS]
else:
    tp_objects = DataFrame()

tp_objects
# Out:
#        y     x  frame  size
# 0  298.6 180.3      0 2.457
# 1  407.3 224.9      0 3.932
# 2  439.5 197.6      0 6.216
# 3  439.5 233.6      0 6.388
# 4  295.2 179.8     10 2.053
# 5  392.3 225.9     10 2.900
# 6  430.4 227.4     10 6.492
# 7  439.7 197.4     10 6.281
# 8  291.8 179.6     20 1.922
# 9  377.4 223.2     20 1.992
# 10 430.3 229.0     20 6.519
# 11 440.7 196.2     20 6.096
# 12 288.0 179.8     30 1.742
# 13 370.5 223.5     30 1.631
# 14 430.4 228.4     30 6.500
# 15 440.8 195.4     30 6.062

# %% [markdown]
# ## Find size from contours
#
# The prior approach throws out contour data, instead operating on filled contours. Instead, try using shapely to find size directly from contour data.

# %% [markdown]
# ### Prepare to find objects
#
# Prepare a dataframe with columns in a certain order, assign contour data to it, and demote the hiearchical indices to plain columns. Count the number of points in each contour and each frame, keeping only those which have enough points to describe a linear ring. Construct a GeoPandas geometry column and operate on it with Shapely to construct linear rings, returning only their centroids. Also report the number of points in the loci of each contour per frame.
#
# :::{admonition} Note: `groupby` considerations
# :class: dropdown note
# `groupby` operations behave differently depending on the index, so resetting the index befoe grouping, and unpacking `GBC` to set sensible defaults for `groupby`'s keyword arguments, makes it behave less surprisingly. `GBC` enables `observed` and `sort`, and disables `as_index`, `dropna`, and `group_keys`.
# :::

# %%
contours = (
    DataFrame(columns=["xpx", "ypx"])
    .assign(**contours_df.loc[IndexSlice[frames, :], :])
    .rename(axis="columns", mapper=dict(xpx="x", ypx="y"))
    .reset_index()
    .assign(
        count=lambda df: df.groupby(["frame", "contour"], **GBC).x.transform("count")
    )
    .query("count > 3")
    .assign(geometry=lambda df: points_from_xy(df.x, df.y))
    .groupby(["frame", "contour"], **GBC)
    .agg(
        count=NamedAgg(column="count", aggfunc="first"),
        centroid=NamedAgg(
            column="geometry", aggfunc=lambda df: LinearRing(df).centroid
        ),
        area=NamedAgg(column="geometry", aggfunc=lambda df: Polygon(df).area),
    )
    .assign(size=lambda df: sqrt(4 * df["area"]) / pi / 4)
    .drop(columns="area")
)
contours
# Out:
#     frame  contour  count                 centroid   size
# 0       0        0     50  POINT (228.015 439.375)  3.215
# 1       0        1     30  POINT (202.637 437.271)  3.193
# 2       0        2     16  POINT (225.105 407.270)  1.202
# 3       0        3      9  POINT (180.189 298.593) 0.7549
# 4      10        1     39  POINT (202.279 437.224)  3.250
# 5      10        2     56  POINT (228.382 438.571)  3.367
# 6      10        3     10  POINT (225.907 392.298) 0.9073
# 7      10        4      8  POINT (179.863 295.137) 0.5627
# 8      20        0     42  POINT (200.723 438.272)  3.335
# 9      20        1     53  POINT (228.308 438.935)  3.367
# 10     20        2      7  POINT (223.194 377.377) 0.4905
# 11     20        3      7  POINT (179.635 291.838) 0.4640
# 12     30        0     51  POINT (229.197 438.948)  3.382
# 13     30        1     41  POINT (200.707 437.914)  3.423
# 14     30        2      4  POINT (223.500 370.500) 0.1592
# 15     30        3      5  POINT (179.746 288.000) 0.3559

# %% [markdown]
# Split the centroid point objects into separate named columns that conform to the Trackpy convention. Report the centroids in each frame.

# %%
objects = (
    GeoDataFrame(contours)
    .assign(x=lambda df: df.centroid.x, y=lambda df: df.centroid.y)
    .loc[:, COLS]
    .sort_values(["frame", "y", "x"], ignore_index=True)
)
objects
# Out:
#        y     x  frame   size
# 0  298.6 180.2      0 0.7549
# 1  407.3 225.1      0  1.202
# 2  437.3 202.6      0  3.193
# 3  439.4 228.0      0  3.215
# 4  295.1 179.9     10 0.5627
# 5  392.3 225.9     10 0.9073
# 6  437.2 202.3     10  3.250
# 7  438.6 228.4     10  3.367
# 8  291.8 179.6     20 0.4640
# 9  377.4 223.2     20 0.4905
# 10 438.3 200.7     20  3.335
# 11 438.9 228.3     20  3.367
# 12 288.0 179.7     30 0.3559
# 13 370.5 223.5     30 0.1592
# 14 437.9 200.7     30  3.423
# 15 438.9 229.2     30  3.382

# %% [markdown]
# ## Compare approaches
#
# Compare Trackpy objects with contour objects. Here the guess radius for Trackpy object finding and contour perimeter filtering are matched to produce the same number of objects from each algorithm. Trackpy features more intelligent filtering, but takes much longer. Trackpy's approach for finding local maxima in grayscale images is applied even to binarized images, exhaustively searching for high points in the binary image, adding to execution time.
#
# The percent difference between the approaches is relatively low for this subset, suggesting the contour centroid approach is reasonable.

# %%
if GET_TRACKPY_OBJECTS:
    diffs = (
        (objects - tp_objects)
        .abs()
        .assign(size=lambda df: df["size"] / tp_objects["size"])
    )

    with style_df(
        DataFrame().assign(
            dx=diffs["x"], dy=diffs["y"], size=diffs["size"], frame=tp_objects.frame
        )
    ) as styler:
        styler.background_gradient().hide(axis="index")
# Out:
# <style type="text/css">
# #T_275d0_row0_col0, #T_275d0_row0_col1, #T_275d0_row0_col3, #T_275d0_row1_col3, #T_275d0_row2_col3, #T_275d0_row3_col3, #T_275d0_row4_col0, #T_275d0_row4_col1, #T_275d0_row5_col0, #T_275d0_row5_col1, #T_275d0_row8_col0, #T_275d0_row9_col0, #T_275d0_row9_col1, #T_275d0_row12_col0, #T_275d0_row12_col1, #T_275d0_row13_col0, #T_275d0_row13_col1, #T_275d0_row15_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_275d0_row0_col2 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_275d0_row1_col0, #T_275d0_row8_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_275d0_row1_col1, #T_275d0_row3_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_275d0_row1_col2 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_275d0_row2_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_275d0_row2_col1 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_275d0_row2_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_275d0_row3_col0 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_275d0_row3_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_275d0_row4_col2 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_275d0_row4_col3, #T_275d0_row5_col3, #T_275d0_row6_col3, #T_275d0_row7_col3 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_275d0_row5_col2 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_275d0_row6_col0 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_275d0_row6_col1 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_275d0_row6_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_275d0_row7_col0 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_275d0_row7_col1 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_275d0_row7_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_275d0_row8_col2 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_275d0_row8_col3, #T_275d0_row9_col3, #T_275d0_row10_col3, #T_275d0_row11_col3 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_275d0_row9_col2 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_275d0_row10_col0 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_275d0_row10_col1, #T_275d0_row12_col3, #T_275d0_row13_col2, #T_275d0_row13_col3, #T_275d0_row14_col3, #T_275d0_row15_col0, #T_275d0_row15_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_275d0_row10_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_275d0_row11_col0 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_275d0_row11_col1 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_275d0_row11_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_275d0_row12_col2 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_275d0_row14_col0 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_275d0_row14_col1 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_275d0_row14_col2 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_275d0_row15_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# </style>
# <table id="T_275d0">
#   <thead>
#     <tr>
#       <th id="T_275d0_level0_col0" class="col_heading level0 col0" >dx</th>
#       <th id="T_275d0_level0_col1" class="col_heading level0 col1" >dy</th>
#       <th id="T_275d0_level0_col2" class="col_heading level0 col2" >size</th>
#       <th id="T_275d0_level0_col3" class="col_heading level0 col3" >frame</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_275d0_row0_col0" class="data row0 col0" >0.07367</td>
#       <td id="T_275d0_row0_col1" class="data row0 col1" >0.01983</td>
#       <td id="T_275d0_row0_col2" class="data row0 col2" >0.6928</td>
#       <td id="T_275d0_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row1_col0" class="data row1 col0" >0.1967</td>
#       <td id="T_275d0_row1_col1" class="data row1 col1" >0.06972</td>
#       <td id="T_275d0_row1_col2" class="data row1 col2" >0.6944</td>
#       <td id="T_275d0_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row2_col0" class="data row2 col0" >5.050</td>
#       <td id="T_275d0_row2_col1" class="data row2 col1" >2.183</td>
#       <td id="T_275d0_row2_col2" class="data row2 col2" >0.4863</td>
#       <td id="T_275d0_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row3_col0" class="data row3 col0" >5.604</td>
#       <td id="T_275d0_row3_col1" class="data row3 col1" >0.08612</td>
#       <td id="T_275d0_row3_col2" class="data row3 col2" >0.4968</td>
#       <td id="T_275d0_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row4_col0" class="data row4 col0" >0.02017</td>
#       <td id="T_275d0_row4_col1" class="data row4 col1" >0.02017</td>
#       <td id="T_275d0_row4_col2" class="data row4 col2" >0.7259</td>
#       <td id="T_275d0_row4_col3" class="data row4 col3" >10</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row5_col0" class="data row5 col0" >0.002872</td>
#       <td id="T_275d0_row5_col1" class="data row5 col1" >0.02664</td>
#       <td id="T_275d0_row5_col2" class="data row5 col2" >0.6871</td>
#       <td id="T_275d0_row5_col3" class="data row5 col3" >10</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row6_col0" class="data row6 col0" >25.07</td>
#       <td id="T_275d0_row6_col1" class="data row6 col1" >6.801</td>
#       <td id="T_275d0_row6_col2" class="data row6 col2" >0.4994</td>
#       <td id="T_275d0_row6_col3" class="data row6 col3" >10</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row7_col0" class="data row7 col0" >30.98</td>
#       <td id="T_275d0_row7_col1" class="data row7 col1" >1.081</td>
#       <td id="T_275d0_row7_col2" class="data row7 col2" >0.4640</td>
#       <td id="T_275d0_row7_col3" class="data row7 col3" >10</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row8_col0" class="data row8 col0" >0.01046</td>
#       <td id="T_275d0_row8_col1" class="data row8 col1" >0.05615</td>
#       <td id="T_275d0_row8_col2" class="data row8 col2" >0.7586</td>
#       <td id="T_275d0_row8_col3" class="data row8 col3" >20</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row9_col0" class="data row9 col0" >0.05534</td>
#       <td id="T_275d0_row9_col1" class="data row9 col1" >0.0001433</td>
#       <td id="T_275d0_row9_col2" class="data row9 col2" >0.7538</td>
#       <td id="T_275d0_row9_col3" class="data row9 col3" >20</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row10_col0" class="data row10 col0" >28.32</td>
#       <td id="T_275d0_row10_col1" class="data row10 col1" >7.968</td>
#       <td id="T_275d0_row10_col2" class="data row10 col2" >0.4885</td>
#       <td id="T_275d0_row10_col3" class="data row10 col3" >20</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row11_col0" class="data row11 col0" >32.07</td>
#       <td id="T_275d0_row11_col1" class="data row11 col1" >1.725</td>
#       <td id="T_275d0_row11_col2" class="data row11 col2" >0.4477</td>
#       <td id="T_275d0_row11_col3" class="data row11 col3" >20</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row12_col0" class="data row12 col0" >0.05930</td>
#       <td id="T_275d0_row12_col1" class="data row12 col1" >5.684e-14</td>
#       <td id="T_275d0_row12_col2" class="data row12 col2" >0.7958</td>
#       <td id="T_275d0_row12_col3" class="data row12 col3" >30</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row13_col0" class="data row13 col0" >0.000</td>
#       <td id="T_275d0_row13_col1" class="data row13 col1" >0.000</td>
#       <td id="T_275d0_row13_col2" class="data row13 col2" >0.9024</td>
#       <td id="T_275d0_row13_col3" class="data row13 col3" >30</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row14_col0" class="data row14 col0" >27.67</td>
#       <td id="T_275d0_row14_col1" class="data row14 col1" >7.481</td>
#       <td id="T_275d0_row14_col2" class="data row14 col2" >0.4734</td>
#       <td id="T_275d0_row14_col3" class="data row14 col3" >30</td>
#     </tr>
#     <tr>
#       <td id="T_275d0_row15_col0" class="data row15 col0" >33.78</td>
#       <td id="T_275d0_row15_col1" class="data row15 col1" >1.897</td>
#       <td id="T_275d0_row15_col2" class="data row15 col2" >0.4421</td>
#       <t

# %% [markdown]
# A warm color palette is used to plot Trackpy objects, and a cool color palette is used to plot contour centroids.

# %%
if GET_TRACKPY_OBJECTS:
    scatterplot(
        ax=ax,
        data=tp_objects,
        x="x",
        y="y",
        hue="frame",
        alpha=0.6,
        palette=WARM_PALETTE,
        legend=False,
    )
scatterplot(
    ax=ax,
    data=objects,
    x="x",
    y="y",
    hue="frame",
    alpha=0.6,
    palette=COOL_PALETTE,
    legend=False,
)

fig = ax.get_figure()
fig
